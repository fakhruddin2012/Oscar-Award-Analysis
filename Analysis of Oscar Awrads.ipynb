# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\Fakhruddin\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_csv('the_oscar_award.csv')
df.head()
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False

# %%
df.shape
# Out:
# (10395, 7)

# %%
df.tail(50)
# Out:
#        year_film  year_ceremony  ceremony                          category  \
# 10345       2019           2020        92                      BEST PICTURE
# 10346       2019           2020        92                      BEST PICTURE
# 10347       2019           2020        92                      BEST PICTURE
# 10348       2019           2020        92                      BEST PICTURE
# 10349       2019           2020        92                      BEST PICTURE
# 10350       2019           2020        92                      BEST PICTURE
# 10351       2019           2020        92                 PRODUCTION DESIGN
# 10352       2019           2020        92                 PRODUCTION DESIGN
# 10353       2019           2020        92                 PRODUCTION DESIGN
# 10354       2019           2020        92                 PRODUCTION DESIGN
# 10355       2019           2020        92                 PRODUCTION DESIGN
# ...

# %%
df.columns
# Out:
# Index(['year_film', 'year_ceremony', 'ceremony', 'category', 'name', 'film',
#        'winner'],
#       dtype='object')

# %%
df.groupby('film')['winner'].value_counts(ascending=False)
# Out:
# film                         winner
# $1,000 a Minute              False     1
# '38'                         False     1
# 'Crocodile' Dundee           False     1
# 'Round Midnight              False     1
#                              True      1
#                                       ..
# the end                      False     1
# tom thumb                    True      1
# À Nous la Liberté            False     1
# Ådalen '31                   False     1
# Éramos Pocos (One Too Many)  False     1
# Name: winner, Length: 5574, dtype: int64
